# %%
import pandas as pd

# %%
# Assigining data to a dictionary
Data = {'fruits':['Apple','Bananna','Watermelon'],
        'No.of fruits':[3,7,2]
       }
# Creating a dataframe using a dictionary
df = pd.DataFrame(Data)

# %%
df
# Out:
#        fruits  No.of fruits
# 0       Apple             3
# 1     Bananna             7
# 2  Watermelon             2

# %%
#list of the attributes and methods of pandas
f= print(dir(pd))
# Out:
# ['BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Float64Index', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int64Index', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt64Index', 'UInt8Dtype', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__getattr__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_config', '_hashtable', '_is_numpy_dev', '_lib', '_libs', '_np_version_under1p18', '_testing', '_tslib', '_typing', '_version', 'api', 'array', 'arrays', 'bdate_range', 'compat', 'c
# ...

# %%
#pandas version
pd.__version__
# Out:
# '1.3.0'

# %%
#Creating a series using pandas

pd_data = [1,12,'34','Sun',False,67.25]
pd_series = pd.Series(pd_data)

print(pd_series)
# Out:
# 0        1
# 1       12
# 2       34
# 3      Sun
# 4    False
# 5    67.25
# dtype: object

# %%
#printing series with index of 1
pd_series[1]
# Out:
# 12

# %%
#printing series with own index
pd_index = pd.Series(pd_data,index=['int','int','int','str','bool','float'])

print(pd_index)
# Out:
# int          1
# int         12
# int         34
# str        Sun
# bool     False
# float    67.25
# dtype: object

# %%
#printing series with index of int
pd_index['int']
# Out:
# int     1
# int    12
# int    34
# dtype: object

# %%
#Creating dataframe with null values
data = {
  "Distance": [420, 380, 390, 400],
  "time": [50, 40, 45, "NULL"],
    "speed": [8.4,9.5,8.7, "NULL"]
}

travel =pd.DataFrame(data)

travel
# Out:
#    Distance  time speed
# 0       420    50   8.4
# 1       380    40   9.5
# 2       390    45   8.7
# 3       400  NULL  NULL

# %%
#printing values of certain row
print(travel.loc[1])
# Out:
# Distance    380
# time         40
# speed       9.5
# Name: 1, dtype: object

# %%
#Printing vales from row to row
print(travel.loc[[0, 1]])
# Out:
#    Distance time speed
# 0       420   50   8.4
# 1       380   40   9.5

# %%
#Creating dataframe with required index
travel1 = pd.DataFrame(data, index = ["day1" , "day2", "day3", "day4"])

# %%
travel1
# Out:
#       Distance  time speed
# day1       420    50   8.4
# day2       380    40   9.5
# day3       390    45   8.7
# day4       400  NULL  NULL

# %%
#reading a CSV file
grades = pd.read_csv('class_grades.csv')

# %%
print(grades.to_string())
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome   Final
# 0        5       57.14     34.09    64.38     51.48   52.50
# 1        8       95.05    105.49    67.50     99.07   68.33
# 2        8       83.70     83.17      NaN     63.15   48.89
# 3        7         NaN       NaN    49.38    105.93   80.56
# 4        8       91.32     93.64    95.00    107.41   73.89
# 5        7       95.00     92.58    93.12     97.78   68.06
# 6        8       95.05    102.99    56.25     99.07   50.00
# 7        7       72.85     86.85    60.00       NaN   56.11
# 8        8       84.26     93.10    47.50     18.52   50.83
# 9        7       90.10     97.55    51.25     88.89   63.61
# 10       7       80.44     90.20    75.00     91.48   39.72
# 11       6         NaN     80.60      NaN       NaN   77.50
# 12       8       97.16    103.71    72.50     93.52   63.33
# 13       7       91.28     83.53    81.25     99.81   92.22
# 14       8       84.80     89.08    44.38     16.91   35.83
# ...

# %%
print(grades)
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17      NaN     63.15  48.89
# 3        7         NaN       NaN    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8         NaN    103.71    45.00     93.52  61.94
# 95       7         NaN     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
print(grades.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Prefix      99 non-null     int64
#  1   Assignment  92 non-null     float64
#  2   Tutorial    96 non-null     float64
#  3   Midterm     96 non-null     float64
#  4   TakeHome    94 non-null     float64
#  5   Final       96 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 4.8 KB
# None

# %%
grades.head(5)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17      NaN     63.15  48.89
# 3       7         NaN       NaN    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
grades.tail(5)
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 94       8         NaN    103.71    45.00     93.52  61.94
# 95       7         NaN     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22

# %%
grades.mean()
# Out:
# Prefix          7.313131
# Assignment     85.738370
# Tutorial       89.606250
# Midterm        68.515833
# TakeHome      819.824468
# Final          68.414375
# dtype: float64

# %%
grades.max()
# Out:
# Prefix           8.00
# Assignment     100.83
# Tutorial       112.58
# Midterm        110.00
# TakeHome      9999.00
# Final          108.89
# dtype: float64

# %%
grades.min()
# Out:
# Prefix         4.00
# Assignment    28.14
# Tutorial      34.09
# Midterm       28.12
# TakeHome      16.91
# Final         28.06
# dtype: float64

# %%
grades.rank()
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0      4.5         4.0       1.5     40.0      10.5   24.0
# 1     73.5        71.0      89.0     44.5      64.5   53.5
# 2     73.5        27.5      23.5      NaN      18.5   15.5
# 3     30.5         NaN       NaN     20.0      81.5   68.0
# 4     73.5        52.5      50.0     89.0      84.5   58.5
# ..     ...         ...       ...      ...       ...    ...
# 94    73.5         NaN      84.5     14.0      51.5   37.0
# 95    30.5         NaN      17.0      8.5      53.5    6.5
# 96    73.5        44.0      78.0     78.0      48.0   78.0
# 97    30.5        76.0      15.0     42.0      67.5   75.5
# 98    73.5         5.5      63.0     56.5      27.0   62.0
#
# [99 rows x 6 columns]

# %%
grades.sum()
# Out:
# Prefix          724.00
# Assignment     7887.93
# Tutorial       8602.20
# Midterm        6577.52
# TakeHome      77063.50
# Final          6567.78
# dtype: float64

# %%
#Droping all the null values and assign to other variable

grades1 =grades.dropna()

print(grades1.to_string())
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome   Final
# 0        5       57.14     34.09    64.38     51.48   52.50
# 1        8       95.05    105.49    67.50     99.07   68.33
# 4        8       91.32     93.64    95.00    107.41   73.89
# 5        7       95.00     92.58    93.12     97.78   68.06
# 6        8       95.05    102.99    56.25     99.07   50.00
# 8        8       84.26     93.10    47.50     18.52   50.83
# 9        7       90.10     97.55    51.25     88.89   63.61
# 10       7       80.44     90.20    75.00     91.48   39.72
# 12       8       97.16    103.71    72.50     93.52   63.33
# 13       7       91.28     83.53    81.25     99.81   92.22
# 14       8       84.80     89.08    44.38     16.91   35.83
# 17       4       92.01    102.52    38.75     86.11   49.17
# 21       8       75.27     97.52    63.12     61.11   66.11
# 22       8       63.78     76.21    39.38     42.22   34.44
# 23       7       80.44     90.20    46.25     91.48   72.22
# ...

# %%
#Droping null values in same dataframe

grades.dropna(inplace=True)
print(grades.to_string())
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome   Final
# 0        5       57.14     34.09    64.38     51.48   52.50
# 1        8       95.05    105.49    67.50     99.07   68.33
# 4        8       91.32     93.64    95.00    107.41   73.89
# 5        7       95.00     92.58    93.12     97.78   68.06
# 6        8       95.05    102.99    56.25     99.07   50.00
# 8        8       84.26     93.10    47.50     18.52   50.83
# 9        7       90.10     97.55    51.25     88.89   63.61
# 10       7       80.44     90.20    75.00     91.48   39.72
# 12       8       97.16    103.71    72.50     93.52   63.33
# 13       7       91.28     83.53    81.25     99.81   92.22
# 14       8       84.80     89.08    44.38     16.91   35.83
# 17       4       92.01    102.52    38.75     86.11   49.17
# 21       8       75.27     97.52    63.12     61.11   66.11
# 22       8       63.78     76.21    39.38     42.22   34.44
# 23       7       80.44     90.20    46.25     91.48   72.22
# ...

# %%
#filling null values with certain value
grades['Final'].fillna(130, inplace = True)
print(grades.to_string)
# Out:
# <bound method DataFrame.to_string of     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 4        8       91.32     93.64    95.00    107.41  73.89
# 5        7       95.00     92.58    93.12     97.78  68.06
# 6        8       95.05    102.99    56.25     99.07  50.00
# ..     ...         ...       ...      ...       ...    ...
# 92       7       95.60     82.28    76.88    108.33  78.33
# 93       8       87.52     91.58    56.25     71.85  85.00
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [81 rows x 6 columns]>

# %%
grades.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00

# %%
#Checking mean of final column
grades['Final'].mean()
# Out:
# 68.09679012345678

# %%
tickets = pd.read_csv('tickets.csv')
tickets.head()
# Out:
#    Stops       Website Booked_on Destination Depart_date Airline      Price
# 0      5  KupiBilet.ru    2/7/22         YTO     4/30/22      WS  Expensive
# 1      4  KupiBilet.ru    2/8/22         ECN     2/27/22      DP      Cheap
# 2      4  KupiBilet.ru    2/5/22         GYE     4/10/22      AV  Expensive
# 3      4  KupiBilet.ru    2/8/22         YVR     5/11/22      WS  Expensive
# 4      4  KupiBilet.ru    2/9/22         LIM     5/11/22      AM  Expensive

# %%
print(tickets.to_string())
# Out:
#       Stops             Website Booked_on Destination Depart_date Airline      Price
# 0         5        KupiBilet.ru    2/7/22         YTO     4/30/22      WS  Expensive
# 1         4        KupiBilet.ru    2/8/22         ECN     2/27/22      DP      Cheap
# 2         4        KupiBilet.ru    2/5/22         GYE     4/10/22      AV  Expensive
# 3         4        KupiBilet.ru    2/8/22         YVR     5/11/22      WS  Expensive
# 4         4        KupiBilet.ru    2/9/22         LIM     5/11/22      AM  Expensive
# 5         4        KupiBilet.ru    2/8/22         YVR     7/17/22      WS  Expensive
# 6         4        KupiBilet.ru    2/7/22         YQB      7/1/22      WS  Expensive
# 7         4        KupiBilet.ru    2/7/22         YVR      6/7/22      WS  Expensive
# 8         4        KupiBilet.ru    2/5/22         AHB     6/19/22      5W  Expensive
# 9         4        KupiBilet.ru    2/7/22         YVR     11/1/22      WS  Expensive
# ...

# %%
#converting a column in a dataframe to datetime format
tickets['Booked_on'] = pd.to_datetime(tickets['Booked_on'])
print(tickets.to_string())
# Out:
#       Stops             Website  Booked_on Destination Depart_date Airline      Price
# 0         5        KupiBilet.ru 2022-02-07         YTO     4/30/22      WS  Expensive
# 1         4        KupiBilet.ru 2022-02-08         ECN     2/27/22      DP      Cheap
# 2         4        KupiBilet.ru 2022-02-05         GYE     4/10/22      DP  Expensive
# 3         4        KupiBilet.ru 2022-02-08         YVR     5/11/22      WS  Expensive
# 4         4        KupiBilet.ru 2022-02-09         LIM     5/11/22      AM  Expensive
# 5         4        KupiBilet.ru 2022-02-08         YVR     7/17/22      WS  Expensive
# 6         4        KupiBilet.ru 2022-02-07         YQB      7/1/22      WS  Expensive
# 7         4        KupiBilet.ru 2022-02-07         YVR      6/7/22      DP  Expensive
# 8         4        KupiBilet.ru 2022-02-05         AHB     6/19/22      5W  Expensive
# 9         4        KupiBilet.ru 2022-02-07         YVR     11/1/22      WS  Expensive
# ...

# %%
tickets.loc[0, 'Stops'] =5

# %%
print(tickets.to_string())
# Out:
#       Stops             Website  Booked_on Destination Depart_date Airline      Price
# 0         5        KupiBilet.ru 2022-02-07         YTO     4/30/22      WS  Expensive
# 1         4        KupiBilet.ru 2022-02-08         ECN     2/27/22      DP      Cheap
# 2         4        KupiBilet.ru 2022-02-05         GYE     4/10/22      DP  Expensive
# 3         4        KupiBilet.ru 2022-02-08         YVR     5/11/22      WS  Expensive
# 4         4        KupiBilet.ru 2022-02-09         LIM     5/11/22      AM  Expensive
# 5         4        KupiBilet.ru 2022-02-08         YVR     7/17/22      WS  Expensive
# 6         4        KupiBilet.ru 2022-02-07         YQB      7/1/22      WS  Expensive
# 7         4        KupiBilet.ru 2022-02-07         YVR      6/7/22      DP  Expensive
# 8         4        KupiBilet.ru 2022-02-05         AHB     6/19/22      5W  Expensive
# 9         4        KupiBilet.ru 2022-02-07         YVR     11/1/22      WS  Expensive
# ...

# %%
print(tickets.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4727    False
# 4728    False
# 4729    False
# 4730    False
# 4731    False
# Length: 4732, dtype: bool

# %%
#Removing duplicates from a dataframe
tickets.drop_duplicates(inplace =True)

# %%
print(tickets.to_string())
# Out:
#       Stops             Website  Booked_on Destination Depart_date Airline      Price
# 0         5        KupiBilet.ru 2022-02-07         YTO     4/30/22      WS  Expensive
# 1         4        KupiBilet.ru 2022-02-08         ECN     2/27/22      DP      Cheap
# 2         4        KupiBilet.ru 2022-02-05         GYE     4/10/22      DP  Expensive
# 3         4        KupiBilet.ru 2022-02-08         YVR     5/11/22      WS  Expensive
# 4         4        KupiBilet.ru 2022-02-09         LIM     5/11/22      AM  Expensive
# 5         4        KupiBilet.ru 2022-02-08         YVR     7/17/22      WS  Expensive
# 6         4        KupiBilet.ru 2022-02-07         YQB      7/1/22      WS  Expensive
# 7         4        KupiBilet.ru 2022-02-07         YVR      6/7/22      DP  Expensive
# 8         4        KupiBilet.ru 2022-02-05         AHB     6/19/22      5W  Expensive
# 9         4        KupiBilet.ru 2022-02-07         YVR     11/1/22      WS  Expensive
# ...

# %%
#Finding all the calculations required on numerical data
grades.describe()
# Out:
#           Prefix  Assignment    Tutorial     Midterm     TakeHome       Final
# count  81.000000   81.000000   81.000000   81.000000    81.000000   81.000000
# mean    7.308642   86.436173   90.197531   69.382840   939.423580   68.096790
# std     0.970077   12.442339   14.996037   19.391849  2803.833341   19.003262
# min     4.000000   28.140000   34.090000   28.120000    16.910000   28.060000
# 25%     7.000000   82.450000   86.650000   54.370000    72.220000   51.670000
# 50%     8.000000   90.980000   94.010000   71.880000    91.480000   66.110000
# 75%     8.000000   95.050000  100.580000   85.000000   100.930000   83.890000
# max     8.000000  100.830000  112.580000  110.000000  9999.000000  108.890000

# %%
#finding correlation between all the numerical data
grades.corr()
# Out:
#               Prefix  Assignment  Tutorial   Midterm  TakeHome     Final
# Prefix      1.000000    0.033643  0.433398 -0.026301 -0.144873  0.108356
# Assignment  0.033643    1.000000  0.403862  0.224236  0.120367  0.290280
# Tutorial    0.433398    0.403862  1.000000  0.163281  0.167233  0.225718
# Midterm    -0.026301    0.224236  0.163281  1.000000 -0.039260  0.724837
# TakeHome   -0.144873    0.120367  0.167233 -0.039260  1.000000 -0.066648
# Final       0.108356    0.290280  0.225718  0.724837 -0.066648  1.000000

# %%
# Plotting entire dataframe using matplotlib
import matplotlib.pyplot as plt

grades.plot()

plt.show()

# %%
# Plotting scatter plot using matplotlib
grades.plot(kind='scatter' , x = 'Assignment' , y = 'Final')
plt.show()

# %%
#Ploting histogram
tickets['Stops'].plot(kind='hist')

# %%
#reading a CSV file
grades = pd.read_csv('class_grades.csv')
grades.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17      NaN     63.15  48.89
# 3       7         NaN       NaN    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
grades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Prefix      99 non-null     int64
#  1   Assignment  92 non-null     float64
#  2   Tutorial    96 non-null     float64
#  3   Midterm     96 non-null     float64
#  4   TakeHome    94 non-null     float64
#  5   Final       96 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 4.8 KB

# %%
#filling null values with mean
grades.Tutorial.fillna(grades.Tutorial.mean(),inplace=True)

# %%
grades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Prefix      99 non-null     int64
#  1   Assignment  92 non-null     float64
#  2   Tutorial    99 non-null     float64
#  3   Midterm     96 non-null     float64
#  4   TakeHome    94 non-null     float64
#  5   Final       96 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 4.8 KB

# %%
#droping all other null values
grades.dropna(inplace = True)

# %%
grades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Prefix      83 non-null     int64
#  1   Assignment  83 non-null     float64
#  2   Tutorial    83 non-null     float64
#  3   Midterm     83 non-null     float64
#  4   TakeHome    83 non-null     float64
#  5   Final       83 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 4.5 KB

# %%
#Printing 1st 10 values of Prefix column
grades.loc[0:10,"Prefix"]
# Out:
# 0     5
# 1     8
# 4     8
# 5     7
# 6     8
# 8     8
# 9     7
# 10    7
# Name: Prefix, dtype: int64

# %%
#Printing all values of TakeHome column
grades.loc[:,"TakeHome"]
# Out:
# 0      51.48
# 1      99.07
# 4     107.41
# 5      97.78
# 6      99.07
#        ...
# 92    108.33
# 93     71.85
# 96     90.74
# 97     99.81
# 98     72.78
# Name: TakeHome, Length: 83, dtype: float64

# %%
var1 = grades.Prefix/grades.TakeHome

var1.sum()
# Out:
# 8.137384826866013

# %%
var1.max()
# Out:
# 0.47309284447072736

# %%
var1.min()
# Out:
# 0.00040004000400040005

# %%
grades.Final/grades.Assignment
# Out:
# 0     0.918796
# 1     0.718885
# 4     0.809133
# 5     0.716421
# 6     0.526039
#         ...
# 92    0.819351
# 93    0.971207
# 96    0.975984
# 97    0.894979
# 98    1.217981
# Length: 83, dtype: float64

# %%
#defining a function
def function(row):
    if row.TakeHome > 100:
        row.TakeHome = 100
        return row
    
grades.apply(function, axis="columns",)
# Out:
# 0                                                  None
# 1                                                  None
# 4     Prefix          8.00
# Assignment     91.32
# Tuto...
# 5                                                  None
# 6                                                  None
#                             ...
# 92    Prefix          7.00
# Assignment     95.60
# Tuto...
# 93                                                 None
# 96                                                 None
# 97                                                 None
# 98                                                 None
# Length: 83, dtype: object

# %%
grades.head(10)
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 4        8       91.32     93.64    95.00    107.41  73.89
# 5        7       95.00     92.58    93.12     97.78  68.06
# 6        8       95.05    102.99    56.25     99.07  50.00
# 8        8       84.26     93.10    47.50     18.52  50.83
# 9        7       90.10     97.55    51.25     88.89  63.61
# 10       7       80.44     90.20    75.00     91.48  39.72
# 12       8       97.16    103.71    72.50     93.52  63.33
# 13       7       91.28     83.53    81.25     99.81  92.22

# %%
grades.describe()
# Out:
#           Prefix  Assignment    Tutorial     Midterm     TakeHome       Final
# count  83.000000   83.000000   83.000000   83.000000    83.000000   83.000000
# mean    7.313253   86.604819   90.183283   69.947470   918.928675   68.791928
# std     0.961804   12.337165   14.812311   19.604683  2772.536354   19.312053
# min     4.000000   28.140000   34.090000   28.120000    16.910000   28.060000
# 25%     7.000000   83.075000   86.660000   54.370000    72.500000   52.085000
# 50%     8.000000   91.280000   93.680000   71.880000    91.480000   66.390000
# 75%     8.000000   95.050000  100.550000   85.625000   100.930000   85.000000
# max     8.000000  100.830000  112.580000  110.000000  9999.000000  108.890000

# %%
grades.corr()
# Out:
#               Prefix  Assignment  Tutorial   Midterm  TakeHome     Final
# Prefix      1.000000    0.035667  0.431565 -0.028628 -0.145643  0.108161
# Assignment  0.035667    1.000000  0.401760  0.234911  0.115629  0.301454
# Tutorial    0.431565    0.401760  1.000000  0.158388  0.167334  0.217960
# Midterm    -0.028628    0.234911  0.158388  1.000000 -0.047008  0.735844
# TakeHome   -0.145643    0.115629  0.167334 -0.047008  1.000000 -0.075598
# Final       0.108161    0.301454  0.217960  0.735844 -0.075598  1.000000

# %%
for x in grades.index:
    if grades.loc[x,"TakeHome"] > 100 :
        grades.loc[x, "TakeHome", ] = 100

# %%
grades.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 4       8       91.32     93.64    95.00    100.00  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00

# %%
grades.corr()
# Out:
#               Prefix  Assignment  Tutorial   Midterm  TakeHome     Final
# Prefix      1.000000    0.035667  0.431565 -0.028628 -0.155483  0.108161
# Assignment  0.035667    1.000000  0.401760  0.234911  0.522513  0.301454
# Tutorial    0.431565    0.401760  1.000000  0.158388  0.212874  0.217960
# Midterm    -0.028628    0.234911  0.158388  1.000000  0.423328  0.735844
# TakeHome   -0.155483    0.522513  0.212874  0.423328  1.000000  0.434690
# Final       0.108161    0.301454  0.217960  0.735844  0.434690  1.000000

# %%
import numpy as np

arr = np.array([[grades.Assignment],[grades.Final]])

# %%
arr
# Out:
# array([[[ 57.14,  95.05,  91.32,  95.  ,  95.05,  84.26,  90.1 ,  80.44,
#           97.16,  91.28,  84.8 ,  92.01,  93.04,  75.27,  63.78,  80.44,
#           53.36,  91.28,  82.45,  91.32,  91.62,  98.58,  86.26,  67.29,
#           98.58,  85.42,  88.09,  95.05,  89.89,  95.  ,  28.14,  95.14,
#           92.01,  86.26,  93.83,  68.95,  85.01,  95.9 ,  92.46,  96.73,
#           83.7 ,  95.14,  98.58,  71.79,  71.79,  87.93,  87.93,  68.95,
#           72.85,  92.02,  90.33,  95.  ,  91.28,  97.  ,  92.02, 100.83,
#           80.53,  90.98,  93.59,  97.33,  84.26,  93.83,  75.27,  92.02,
#           97.16,  66.17,  81.22,  74.29,  97.33,  86.86,  95.6 ,  87.93,
#           98.49,  74.35,  86.29,  97.  ,  97.33,  96.41,  95.6 ,  87.52,
#           89.94,  95.6 ,  63.4 ]],
#
#        [[ 52.5 ,  68.33,  73.89,  68.06,  50.  ,  50.83,  63.61,  39.72,
#           63.33,  92.22,  35.83,  49.17,  91.11,  66.11,  34.44,  72.22,
# ...

# %%
arr.ndim
# Out:
# 3

# %%
grades.loc[5:10]
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 5        7       95.00     92.58    93.12     97.78  68.06
# 6        8       95.05    102.99    56.25     99.07  50.00
# 8        8       84.26     93.10    47.50     18.52  50.83
# 9        7       90.10     97.55    51.25     88.89  63.61
# 10       7       80.44     90.20    75.00     91.48  39.72

# %%
for x in grades.index:
    
    if grades.loc[x,"TakeHome"] > 90 :
        print(grades.loc[x, "TakeHome", ])
# Out:
# 99.07
# 100.0
# 97.78
# 99.07
# 91.48
# 93.52
# 99.81
# 91.48
# 100.0
# 97.59
# 100.0
# 97.59
# 100.0
# 100.0
# 93.7
# 100.0
# 100.0
# 97.41
# 100.0
# 100.0
# 97.41
# 100.0
# 99.81
# 100.0
# 100.0
# 96.85
# 100.0
# 94.44
# 95.93
# 100.0
# 100.0
# 100.0
# 99.81
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 100.0
# 90.74
# 99.81

# %%
var2 =grades.TakeHome.map(lambda x: x - grades.TakeHome.mean())

type(var2)
# Out:
# pandas.core.series.Series

# %%
print(var2.max())
# Out:
# 16.814939759036122

# %%
var3 = (grades.Assignment/grades.TakeHome)

print(type(var3))
# Out:
# <class 'pandas.core.series.Series'>

# %%
z= var3.max()

# %%
grades.Prefix.map(grades.Prefix > 60)
# Out:
# 0     False
# 1     False
# 4     False
# 5       NaN
# 6     False
#       ...
# 92      NaN
# 93    False
# 96    False
# 97      NaN
# 98    False
# Name: Prefix, Length: 83, dtype: object
